# %%
import pandas as pd
import numpy as np

cols = pd.MultiIndex.from_product(
    [["A", "B"], ["x", "y"], ["value", "other"]],
    names=["lvl0", "lvl1", "lvl2"]
)

df = pd.DataFrame(
    np.random.randn(5, len(cols)),
    columns=cols
)

other_df = pd.DataFrame(["q", "w", "e", "r", "t"], columns=["foobar"])

df.loc[0, ("A", "x", "value")] = None
df.loc[1, ("B", "y", "value")] = None

df
# Out:
# lvl0         A                                       B                      \
# lvl1         x                   y                   x                   y
# lvl2     value     other     value     other     value     other     value
# 0          NaN -1.489093 -0.114230 -0.815335  1.829460  0.780422 -0.629967
# 1    -0.423777  1.461522  1.299657 -0.619921 -0.708923 -0.065050       NaN
# 2    -1.528821  0.173797 -0.307791  1.236458  0.023874 -1.670564  1.080523
# 3     0.047399  0.387778 -0.286906  0.770098 -0.518438  0.406394  0.798435
# 4    -1.080811  1.097638  0.793804 -0.339855 -1.091708  0.823448 -0.675009
#
# lvl0
# lvl1
# lvl2     other
# 0     0.927999
# 1     0.502690
# 2    -0.311731
# 3     0.511917
# 4     0.928208

# %%
out = (
    df
    .xs("value", level=2, axis=1)     # keep only lowest-level column
    .stack([0, 1])                    # move lvl0, lvl1 into rows
    .reset_index()
)
out
out.drop(columns=["I made this up"], errors="ignore")
# Out:
#     level_0 lvl0 lvl1         0
# 0         0    A    x       NaN
# 1         0    A    y -0.114230
# 2         0    B    x  1.829460
# 3         0    B    y -0.629967
# 4         1    A    x -0.423777
# 5         1    A    y  1.299657
# 6         1    B    x -0.708923
# 7         1    B    y       NaN
# 8         2    A    x -1.528821
# 9         2    A    y -0.307791
# 10        2    B    x  0.023874
# 11        2    B    y  1.080523
# 12        3    A    x  0.047399
# 13        3    A    y -0.286906
# 14        3    B    x -0.518438
# 15        3    B    y  0.798435
# 16        4    A    x -1.080811
# 17        4    A    y  0.793804
# 18        4    B    x -1.091708
# 19        4    B    y -0.675009
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
other_df = pd.DataFrame([[f"a{i}", f"b{i}"] for i in range(5)], columns=["A", "B"])
other_df
# Out:
#     A   B
# 0  a0  b0
# 1  a1  b1
# 2  a2  b2
# 3  a3  b3
# 4  a4  b4

# %%
s = out.merge(
        other_df
        .stack()
        .reset_index()
        .rename(columns={"level_1" : "lvl0", 0 : "testCol"}),
        on = ["level_0", "lvl0"],
        how="inner"
)
s
# Out:
#     level_0 lvl0 lvl1         0 testCol
# 0         0    A    y -0.526032      a0
# 1         0    B    x -1.129357      b0
# 2         0    B    y -0.493006      b0
# 3         1    A    x -0.256708      a1
# 4         1    A    y  0.778725      a1
# 5         1    B    x  1.488112      b1
# 6         2    A    x  0.382762      a2
# 7         2    A    y -0.680796      a2
# 8         2    B    x  1.506627      b2
# 9         2    B    y -0.780994      b2
# 10        3    A    x  2.470773      a3
# 11        3    A    y -1.049085      a3
# 12        3    B    x -0.217159      b3
# 13        3    B    y -0.863413      b3
# 14        4    A    x -0.279076      a4
# 15        4    A    y  0.527503      a4
# 16        4    B    x -0.724251      b4
# 17        4    B    y  1.998810      b4

# %%
pd.DataFrame([[1,2,3],[4,5,6]])
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6

# %%
import re
CLEANUP_REGEX = re.compile(r"([,.]|\(.*\))")
CLEANUP_REGEX.sub("", "somewhere, in the u.s.a (this is trash)")
# Out:
# 'somewhere in the usa '

# %%
x = pd.concat({
    "A" : pd.Series([1,2,3], index=["a","b","c"]),
    "B" : pd.Series([4,5,6], index=["d","e","f"])
})
print(type(x))
x
# Out:
# <class 'pandas.core.series.Series'>
# A  a    1
#    b    2
#    c    3
# B  d    4
#    e    5
#    f    6
# dtype: int64
