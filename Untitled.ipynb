# %%
import pandas as pd
import numpy as np

cols = pd.MultiIndex.from_product(
    [["A", "B"], ["x", "y"], ["value", "other"]],
    names=["lvl0", "lvl1", "lvl2"]
)

df = pd.DataFrame(
    np.random.randn(5, len(cols)),
    columns=cols
)

other_df = pd.DataFrame(["q", "w", "e", "r", "t"], columns=["foobar"])

df.loc[0, ("A", "x", "value")] = None
df.loc[1, ("B", "y", "value")] = None

df
# Out:
# lvl0         A                                       B                      \
# lvl1         x                   y                   x                   y
# lvl2     value     other     value     other     value     other     value
# 0          NaN -0.982548  0.714387 -0.445546  1.887733  1.713493 -0.779232
# 1    -0.002364 -0.594216 -0.883860 -1.279287  0.125930  0.173256       NaN
# 2     0.076178  0.292727 -0.641336  0.876850  0.123310  0.315205 -1.332491
# 3     1.969892 -0.837954  0.168067 -0.629897  0.036094 -0.374246 -0.111006
# 4    -0.332755  1.056354 -0.754293 -0.300903 -1.297966  0.191398 -0.559698
#
# lvl0
# lvl1
# lvl2     other
# 0    -2.006016
# 1    -0.323636
# 2     0.235018
# 3    -1.086013
# 4     0.158198

# %%
out = (
    df
    .xs("value", level=2, axis=1)     # keep only lowest-level column
    .stack([0, 1])                    # move lvl0, lvl1 into rows
    .reset_index()
)
out
# Out:
# /tmp/ipykernel_13610/3546502626.py:4: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   .stack([0, 1])                    # move lvl0, lvl1 into rows
#     level_0 lvl0 lvl1         0
# 0         0    A    y -0.526032
# 1         0    B    x -1.129357
# 2         0    B    y -0.493006
# 3         1    A    x -0.256708
# 4         1    A    y  0.778725
# 5         1    B    x  1.488112
# 6         2    A    x  0.382762
# 7         2    A    y -0.680796
# 8         2    B    x  1.506627
# 9         2    B    y -0.780994
# 10        3    A    x  2.470773
# 11        3    A    y -1.049085
# 12        3    B    x -0.217159
# 13        3    B    y -0.863413
# 14        4    A    x -0.279076
# 15        4    A    y  0.527503
# 16        4    B    x -0.724251
# 17        4    B    y  1.998810

# %%
other_df = pd.DataFrame([[f"a{i}", f"b{i}"] for i in range(5)], columns=["A", "B"])
other_df
# Out:
#     A   B
# 0  a0  b0
# 1  a1  b1
# 2  a2  b2
# 3  a3  b3
# 4  a4  b4

# %%
s = out.merge(
        other_df
        .stack()
        .reset_index()
        .rename(columns={"level_1" : "lvl0", 0 : "testCol"}),
        on = ["level_0", "lvl0"],
        how="inner"
)
s
# Out:
#     level_0 lvl0 lvl1         0 testCol
# 0         0    A    y -0.526032      a0
# 1         0    B    x -1.129357      b0
# 2         0    B    y -0.493006      b0
# 3         1    A    x -0.256708      a1
# 4         1    A    y  0.778725      a1
# 5         1    B    x  1.488112      b1
# 6         2    A    x  0.382762      a2
# 7         2    A    y -0.680796      a2
# 8         2    B    x  1.506627      b2
# 9         2    B    y -0.780994      b2
# 10        3    A    x  2.470773      a3
# 11        3    A    y -1.049085      a3
# 12        3    B    x -0.217159      b3
# 13        3    B    y -0.863413      b3
# 14        4    A    x -0.279076      a4
# 15        4    A    y  0.527503      a4
# 16        4    B    x -0.724251      b4
# 17        4    B    y  1.998810      b4

# %%
pd.DataFrame([[1,2,3],[4,5,6]])
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6

# %%
import re
CLEANUP_REGEX = re.compile(r"([,.]|\(.*\))")
CLEANUP_REGEX.sub("", "somewhere, in the u.s.a (this is trash)")
# Out:
# 'somewhere in the usa '

# %%
x = pd.concat({
    "A" : pd.Series([1,2,3], index=["a","b","c"]),
    "B" : pd.Series([4,5,6], index=["d","e","f"])
})
print(type(x))
x
# Out:
# <class 'pandas.core.series.Series'>
# A  a    1
#    b    2
#    c    3
# B  d    4
#    e    5
#    f    6
# dtype: int64
