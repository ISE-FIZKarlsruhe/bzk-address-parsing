# %% [markdown]
# Geonames lowest level of granularity goes to either relevant buildings (historically relevant or establishments such as hotels) or city regions. Buildings do not point to the respective city region.
#
# Recommendation regarding ontology:
#
# ```
# ?addressEntity a ontology:address
# ?addressEntity ontology:geonameLocation> ?lowestPossibleGeoname
# ?addressEntity ontology:fullAddress ?fullAddressString
# Other fields such as street, building number and postal code?
# ```
#
# Conclusions from analyzing Karlsruhe.
