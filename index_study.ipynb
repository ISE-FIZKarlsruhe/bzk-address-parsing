# %%
import modules.geo_db_search as geo_db_search
import pandas

if "conn" in globals():
    globals()["conn"].close() # Allow script rerunning

tantivy = geo_db_search.TantivySearchIndex(".geo_db_search_index/tantivy_index")
geo_db_searcher = geo_db_search.GeoDBSearch(":memory:", search_index=tantivy)
print("Initializing GeoDB searcher...")
geo_db_searcher.initialize()
conn = geo_db_searcher.connection
# Out:
# Initializing GeoDB searcher...
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Populating Tantivy index with 24382220 names from the geonames database...
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))
# Populating Tantivy index:   0%|          | 0/24382220 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 10
#       8 geo_db_searcher = geo_db_search.GeoDBSearch(":memory:", search_index=tantivy)
#       9 print("Initializing GeoDB searcher...")
# ---> 10 geo_db_searcher.initialize()
#      11 conn = geo_db_searcher.connection
#
# File ~/bzk-post-processing/modules/geo_db_search.py:599, in initialize(self)
#     598 def finalize(self):
# --> 599     self.connection.close()
#     600     return super().finalize()
#
# ...

# %%
unique_words = conn.execute(geo_db_search.UNIQUE_WORDS_QUERY).fetch_df()
# Out:
# FloatProgress(value=0.0, layout=Layout(width='auto'), style=ProgressStyle(bar_color='black'))

# %%
print(f"{len(unique_words):_} unique words in geographical_names_with_entities")
unique_words.sort_values(by="freq", inplace=True, ascending=False)
unique_words
# Out:
# 7_404_996 unique words in geographical_names_with_entities
#                         word    freq
# 100384                    el  769022
# 186378                    de  664456
# 15                     creek  654299
# 147480                    la  636679
# 2072                  school  600940
# ...                      ...     ...
# 5488371  chaeyanggol-soryuji       1
# 5488359            werklusse       1
# 5488356         oberschoeckl       1
# 5488375   munseong-junggogyo       1
# 5488372             t’oso-ri       1
#
# [7404996 rows x 2 columns]
